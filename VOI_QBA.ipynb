# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# !pip install -q lets-plot
from lets_plot import *
LetsPlot.setup_html()

# %%
# 1. Parameters and Setups

# simulation settings
n_out = 5000 #5000
n_in = 20000 #20000
np.random.seed(2026)

# economic and utility
wtp = 150000          # Lambda ($/QALY)
qaly_no_event = 0.8
qaly_event = 0.2
cost_sc = 50000
cost_nt = 60000

# true values
p_sc = 0.3

# Variance of theta function
def get_var_theta(theta, n_sc, n_nt, p_sc=p_sc):
    rr = np.exp(theta)
    p_nt = p_sc * rr

    a = n_sc * p_sc
    var_sc = 1/a - 1/n_sc
    c = n_nt * p_nt
    var_nt = 1/c - 1/n_nt

    return var_nt + var_sc

# study designs
## policy 1: trial
trial_cost=5*1e6
n_trial = 400
n_trial_sc = 0.5*n_trial
n_trial_nt = 0.5*n_trial
tau_trial = 4 # years to results

## polity 2: RWE
bias_b = 0.3
n_rwe=4000
n_rwe_sc=0.5*n_rwe
n_rwe_nt=0.5*n_rwe
delta_tau_rwe=2 # 2 years advance in time

# population
I_t = 10000 # annual cohort
total_yrs = 10 #  time horizon
discount_rate = 0.03
update_rate = 0.3

# %%
# 2. Helper Functions

# Posterior update (normal-normal)
def get_posterior_mean_variance(prior_mean, prior_var, data_mean, data_var):

    # Normal-Normal Conjugate
    prior_prec = 1.0 / prior_var
    data_prec = 1.0 / data_var
    post_prec = prior_prec + data_prec

    post_var = 1.0 / post_prec
    post_mean = post_var * (prior_mean * prior_prec + data_mean * data_prec)

    return post_mean, post_var

  # Net benefit
def calculate_net_benefit(theta, cost, qaly_no_event=qaly_no_event, qaly_event=qaly_event, p_sc=p_sc):
    """Calculates NHB = E[QALYs] - Cost/WTP"""
    prob_event = np.exp(theta) * p_sc
    expected_qaly = (1 - prob_event)*qaly_no_event + prob_event*qaly_event
    return expected_qaly - cost/wtp

# %%
# Nested benefit
def calculate_nested_benefit(rr_prior_mean, bias_b=bias_b, n_out=n_out, n_in=n_in):

    theta_prior_mean = np.log(rr_prior_mean)
    theta_prior_var = get_var_theta(
        p_sc = p_sc,
        theta = theta_prior_mean,
        n_sc = 100,
        n_nt = 100)

    # Net Benefit of SC (constant)
    nb_sc = calculate_net_benefit(theta=0, cost=cost_sc)

    # Prior Only World (True World)
    theta_prior = np.random.normal(theta_prior_mean, np.sqrt(theta_prior_var), n_out)
    nb_nt_per_draw = calculate_net_benefit(theta_prior, cost_nt)
    nb_nt = np.mean(nb_nt_per_draw)

    # --- Policy 1: Trial Strategy ---
    # Generate Unbiased Trial Data (X_bar)
    var_trial = get_var_theta(theta_prior, n_trial_sc, n_trial_nt)
    X_bar = np.random.normal(theta_prior, np.sqrt(var_trial))

    # Decision Making (Posterior Belief based on X_bar)
    post_mean_trial, post_var_trial = get_posterior_mean_variance(
        prior_mean=theta_prior_mean,
        prior_var=theta_prior_var,
        data_mean=X_bar,
        data_var=var_trial
    )

    # Calculate Expected NB from the Decision Maker's perspective
    dec_samples_trial = np.random.normal(
        loc=post_mean_trial[:, np.newaxis],
        scale=np.sqrt(post_var_trial[:, np.newaxis]),
        size=(n_out, n_in)
    )
    # Perceived Expected NB of NT (Average across posterior samples, axis=1)
    expected_nb_nt_trial = np.mean(calculate_net_benefit(dec_samples_trial, cost_nt), axis=1)

    # Decision Rule: Choose NT if Expected NB > NB_SC
    choose_nt_trial = expected_nb_nt_trial > nb_sc

    # Realized Payoff (Use TRUE NB)
    payoff_trial = np.where(choose_nt_trial, nb_nt_per_draw, nb_sc)
    nb_trial = np.mean(payoff_trial)

    # --- Policy 2: RWE Strategy ---
    # Hypothetical Trial with sample sizes as RWE
    hypo_var_trial = get_var_theta(theta_prior, n_rwe_sc, n_rwe_nt)
    hypo_X_bar = np.random.normal(theta_prior, np.sqrt(hypo_var_trial))

    # Generate Biased RWE Data (R_bar)
    biased_mean_true = hypo_X_bar + np.log(bias_b)
    var_rwe = get_var_theta(biased_mean_true, n_rwe_sc, n_rwe_nt)
    R_bar = np.random.normal(biased_mean_true, np.sqrt(var_rwe))

    # Decision Making (Posterior Belief based on R_bar)
    post_mean_rwe, post_var_rwe = get_posterior_mean_variance(
        prior_mean=theta_prior_mean,
        prior_var=theta_prior_var,
        data_mean=R_bar,
        data_var=var_rwe
    )

    # Calculate Expected NB from Decision Maker's perspective
    dec_samples_rwe = np.random.normal(
        loc=post_mean_rwe[:, np.newaxis],
        scale=np.sqrt(post_var_rwe[:, np.newaxis]),
        size=(n_out, n_in)
    )

    # Perceived Expected NB of NT
    expected_nb_nt_rwe = np.mean(calculate_net_benefit(dec_samples_rwe, cost_nt), axis=1)

    # Decision Rule
    choose_nt_rwe = expected_nb_nt_rwe > nb_sc

    # Realized Payoff
    payoff_rwe = np.where(choose_nt_rwe, nb_nt_per_draw, nb_sc)
    nb_rwe = np.mean(payoff_rwe)

    return {
        "nb_nt_per_draw": nb_nt_per_draw,
        "nb_trial_per_draw": payoff_trial,
        "nb_rwe_per_draw": payoff_rwe,
        "nb_sc": nb_sc,
        "nb_nt": nb_nt,
        "nb_trial": nb_trial,
        "nb_rwe": nb_rwe
    }

# %%
# Policy Net Benefit
def get_policy_nb(rr_prior_mean, bias_b=bias_b, delta_tau_rwe=delta_tau_rwe, trial_cost=trial_cost,
                  n_out=n_out, n_in=n_in):

  # NBs
  res = calculate_nested_benefit(rr_prior_mean=rr_prior_mean,
                                 bias_b=bias_b, n_out=n_out, n_in=n_in)

  nb_sc = res["nb_sc"]
  nb_nt = res["nb_nt"]
  nb_trial = res["nb_trial"]
  nb_rwe = res["nb_rwe"]
  nb_nt_per_draw = res["nb_nt_per_draw"]
  nb_trial_per_draw = res["nb_trial_per_draw"]
  nb_rwe_per_draw = res["nb_rwe_per_draw"]

  # --- Policy 1: Trial ---
  # Trial population payoff (during trial)
  trial_pop_nb = n_trial_sc * nb_sc + n_trial_nt * nb_nt - trial_cost/wtp

  # Population waiting for trial results (Standard of Care)
  discounted_pop_waiting = np.sum([I_t / ((1 + discount_rate)**t) for t in range(1, tau_trial + 1)])
  before_trial_pop_nb = (discounted_pop_waiting+I_t-n_trial) * nb_sc

  # Population after trial results (t > tau_trial)
  discounted_pop_after = np.sum([I_t / ((1 + discount_rate)**t) for t in range(tau_trial + 1, total_yrs)])
  expected_nb_after = update_rate * nb_trial + (1 - update_rate) * nb_sc
  after_trial_pop_nb = discounted_pop_after * expected_nb_after

  # Total Policy 1 Payoff
  policy_1_total = trial_pop_nb + before_trial_pop_nb + after_trial_pop_nb

  # --- Policy 2: RWE ---
  # 1. Before RWE results
  cutoff_rwe = tau_trial - delta_tau_rwe
  discounted_pop_before_rwe = np.sum([I_t / ((1 + discount_rate)**t) for t in range(0, cutoff_rwe + 1)])
  expected_nb_before_rwe = update_rate * nb_nt + (1 - update_rate) * nb_sc
  policy_2_before = discounted_pop_before_rwe * expected_nb_before_rwe

  # 2. After RWE results (t > tau - delta_tau)
  discounted_pop_after_rwe = np.sum([I_t / ((1 + discount_rate)**t) for t in range(cutoff_rwe + 1, total_yrs)])
  expected_nb_after_rwe = update_rate * nb_rwe + (1 - update_rate) * nb_sc
  policy_2_after = discounted_pop_after_rwe * expected_nb_after_rwe

  policy_2_total = policy_2_before + policy_2_after

  # --- Prob that policy 1 dominates ---
  trial_pop_nb_per_draw = n_trial_sc * nb_sc + n_trial_nt * nb_nt_per_draw - trial_cost/wtp
  expected_nb_after_trial_per_draw = update_rate * nb_trial_per_draw + (1 - update_rate) * nb_sc
  after_trial_pop_nb_per_draw = discounted_pop_after * expected_nb_after_trial_per_draw
  policy_1_per_draw = trial_pop_nb_per_draw + before_trial_pop_nb + after_trial_pop_nb_per_draw

  expected_nb_before_rwe_per_draw = update_rate * nb_nt_per_draw + (1 - update_rate) * nb_sc
  policy_2_before_per_draw = discounted_pop_before_rwe * expected_nb_before_rwe_per_draw
  expected_nb_after_rwe_per_draw = update_rate * nb_rwe_per_draw + (1 - update_rate) * nb_sc
  policy_2_after_per_draw = discounted_pop_after_rwe * expected_nb_after_rwe_per_draw
  policy_2_per_draw = policy_2_before_per_draw + policy_2_after_per_draw

  prop_policy1 = np.mean(policy_1_per_draw > policy_2_per_draw)

  return {
      "p1": policy_1_total,
      "p2": policy_2_total,
      "prob_p1": prop_policy1
  }

# %% [markdown]
# # Figure 1: Population-level expected net benefit under alternative CED policies as a funciton of RWE bias

# %%
scaler=1.3

# Custom colors
colors = {
    'Policy 1: RCT-based CED': '#E41A1B',
    'Policy 2: RWE-based CED': '#377EB8'
}

# Add font family configuration
times_new_roman_theme = theme(
    # title=element_text(size=12*scaler, family="Times New Roman"),
    axis_text_x=element_text(size=10*scaler, family="Times New Roman", angle=0),
    axis_text_y=element_text(size=10*scaler, family="Times New Roman"),
    legend_text=element_text(size=11*scaler, family="Times New Roman"),
    legend_position="bottom",  # Move legend to the bottom
    legend_direction="horizontal",
    legend_title=element_text(size=12*scaler, family="Times New Roman"),
    plot_title=element_text(size=16, family="Times New Roman", face = "bold"),
    plot_subtitle=element_text(size=14, family="Times New Roman"),
    axis_title_x=element_text(size=12*scaler, family="Times New Roman"),
    axis_title_y=element_text(size=12*scaler, family="Times New Roman"),
    text=element_text(size=8, family="Times New Roman")
)

# %%
range1 = np.linspace(0.01, 1, 40)
range2 = np.linspace(1, 3, 61)[1:]
bias_b_range = np.concatenate((range1, range2))

# %% [markdown]
# ## Base True RR = 0.63

# %%
# Figure 1: Expected Net Benefits under RWE bias
# Data Preparation

rr_true = 0.63

results_p1 = []
for b in bias_b_range:
    res = get_policy_nb(rr_prior_mean=rr_true, bias_b=b, n_out=n_out, n_in=n_in)
    p1 = res["p1"]
    p2 = res["p2"]
    prop_p1 = res["prob_p1"]
    results_p1.append({'bias_b': b, 'Policy 1: RCT-based CED': p1, 'Policy 2: RWE-based CED': p2, 'Prob':prop_p1})

df_p1 = pd.DataFrame(results_p1)

# Find intersection using linear interpolation
diffs_p1 = df_p1['Policy 1: RCT-based CED'] - df_p1['Policy 2: RWE-based CED']
idx_p1 = np.where(np.diff(np.sign(diffs_p1)))[0]
all_intersections_p1 = []

for i in idx_p1:
   x1, x2 = df_p1.bias_b.iloc[i], df_p1.bias_b.iloc[i+1]
   y1, y2 = diffs_p1.iloc[i], diffs_p1.iloc[i+1]

   if not np.isclose(y2 - y1, 0.0):
       intersect_val = x1 + (x2 - x1) * (0 - y1) / (y2 - y1)
       all_intersections_p1.append(intersect_val)

# Filter logic for pib_p1
pib_p1 = []
if len(all_intersections_p1) > 0:
    if len(all_intersections_p1) == 1:
        pib_p1 = all_intersections_p1
    else:
        # Save smallest and largest
        pib_p1 = [min(all_intersections_p1), max(all_intersections_p1)]

pib_p1 = sorted(list(set(pib_p1)))

# %%
if len(pib_p1) >= 2:
    print(f"PIB Range: {pib_p1[0]:.2f} to {pib_p1[-1]:.2f}")
    print(f"Note: Within this range ({pib_p1[0]:.2f} < Bias < {pib_p1[-1]:.2f}), Policy 2 (RWE-based CED) yields higher expected net benefit.")
elif len(pib_p1) == 1:
    print(f"PIB Value: {pib_p1[0]:.2f}")
    if pib_p1[0] > 1.0:
         print(f"Note: For Bias < {pib_p1[0]:.2f}, Policy 2 (RWE-based CED) yields higher expected net benefit.")
    else:
         print(f"Note: For Bias > {pib_p1[0]:.2f}, Policy 2 (RWE-based CED) yields higher expected net benefit.")
else:
    print("No intersection found.")
# Out:
# PIB Range: 0.78 to 1.30
# Note: Within this range (0.78 < Bias < 1.30), Policy 2 (RWE-based CED) yields higher expected net benefit.

# %%
# Figure 1: Expected Net Benefits under RWE bias
# Save data

fig_dat_path = "/content/drive/MyDrive/Research/02_VOI_RWE_QBA/03_output/stats"
df_p1.to_csv(f"{fig_dat_path}/df_p1.csv", index=False)

# Save intersections
pd.DataFrame({'pib_p1': pib_p1}).to_csv(f"{fig_dat_path}/pib_p1.csv", index=False)

# %%
from textwrap import fill
# Figure 1: Expected Net Benefits under RWE bias
# Plotting

rr_true = 0.63

# Read files
fig_dat_path = "/content/drive/MyDrive/Research/02_VOI_RWE_QBA/03_output/stats"
df_p1 = pd.read_csv(f"{fig_dat_path}/df_p1.csv")

# Melt for plotting
df_plot = pd.melt(df_p1, id_vars=['bias_b', 'Prob'],
                  value_vars=['Policy 1: RCT-based CED', 'Policy 2: RWE-based CED'],
                  var_name='Policy Scenario', value_name='Net Benefit')

df_plot['Net Benefit'] = df_plot['Net Benefit']/1000

# Read pib_p1 and convert back to list for consistency
pib_p1_df = pd.read_csv(f"{fig_dat_path}/pib_p1.csv")
pib_p1 = pib_p1_df['pib_p1'].tolist()

fig1 = (
    ggplot(df_plot, aes(x="bias_b", y="Net Benefit", color="Policy Scenario"))
    + geom_line(size=1.2)
    + scale_color_manual(values=colors)
    + scale_x_continuous(name="RWE Bias Factor (B)", format=".1f")
    + scale_y_continuous(name="Population Expected Net Benefit (1K QALYs)", format=".2f", limits=(25.00, 25.36))
    + theme_bw()
    + times_new_roman_theme
    + theme(legend_title=element_blank())
)

y_top = df_plot['Net Benefit'].max()

prd = df_p1.loc[df_p1["bias_b"] == 1, "Prob"].iloc[0]

# Add PIBs
if len(pib_p1) >= 2:
    pib1_min = min(pib_p1)
    pib1_max = max(pib_p1)

    fig1 += geom_vline(xintercept=pib1_min, linetype="dashed",color='black',size=0.8)
    fig1 += geom_vline(xintercept=pib1_max, linetype="dashed",color='black',size=0.8)
    fig1 += geom_label(
        aes(x='x',y='y',label='label'),
        data=pd.DataFrame({
            'x': [pib1_min, pib1_max],
            'y': [25.005, 25.005],
            'label': [f"{pib1_min:.2f}", f"{pib1_max:.2f}"]
        }),
        color='black', size=7, fill='white', family='Times New Roman',
        inherit_aes=False
    )

# Add PRD Label
fig1 += geom_label(
    x=3.0-0.15, y=y_top+0.02,
    label=f"PRD = {prd:.1%}",
    size = 7,
    fill='white', color='black', family='Times New Roman'
)

fig1
# Out:
# <html lang="en">
#    <head>
#        <meta charset="UTF-8">
#        <style> html, body { margin: 0; padding: 0; } </style>
#        <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.2/js-package/distr/lets-plot.min.js"></script>
#    </head>
#    <body>
#           <div id="p2MPdu" ></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("p2MPdu");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "bias_b":[0.01,0.0353846153846153,0.0607692307692307,0.0861538461538461,0.1115384615384615,0.1369230769230769,0.1623076923076923,0.1876923076923076,0.213076923076923,0.2384615384615384,0.2638461538461538,0.2892307692307692,0.3146153846153846,0.34,0.3653846153846153,0.3907692307692307,0.4161538461538461,0.4415384615384615,0.4669230769230769,0.4923076923076923,0.5176923076923077,0.5430769230769231,0.5684615384615385,0.5938461538461538,0.6192307692307693,0.6446153846153846,0.67,0.6953846153846154,0.7207692307692307,0.7461538461538462,0.7715384615384615,0.796923076923077,0.8223076923076923,0.8476923076923076,0.8730769230769231,0.8984615384615384,0.923846153846154,0.9492307692307692,0.9746153846153846,1.0,1.0333333333333334,1.0666666666666669,1.1,1.1333333333333333,1.1666666666666667,1.2,1.2333333333333334,1.2666666666666666,1.3,1.3333333333333333,1.3666666666666667,1.4,1.4333333333333331,1.4666666666666668,1.5,1.5333333333333332,1.5666666666666669,1.6,1.6333333333333333,1.6666666666666663,1.7,1.7333333333333334,1.7666666666666666,1.8,1.8333333333333333,1.8666666666666667,1.9,1.9333333333333331,1.9666666666666668,2.0,2.033333333333333,2.0666666666666664,2.1,2.1333333333333333,2.166666666666667,2.2,2.2333333333333334,2.2666666666666666,2.3,2.333333333333333,2.3666666666666667,2.4,2.4333333333333336,2.466666666666667,2.5,2.533333333333333,2.5666666666666664,2.6,2.6333333333333333,2.666666666666667,2.7,2.7333333333333334,2.7666666666666666,2.8,2.833333333333333,2.8666666666666667,2.9,2.9333333333333336,2.966666666666667,3.0,0.01,0.0353846153846153,0.0607692307692307,0.0861538461538461,0.1115384615384615,0.1369230769230769,0.1623076923076923,0.1876923076923076,0.213076923076923,0.2384615384615384,0.2638461538461538,0.2892307692307692,0.3146153846153846,0.34,0.3653846153846153,0.3907692307692307,0.4161538461538461,0.4415384615384615,0.4669230769230769,0.4923076923076923,0.5176923076923077,0.5430769230769231,0.5684615384615385,0.5938461538461538,0.6192307692307693,0.6446153846153846,0.67,0.6953846153846154,0.7207692307692307,0.7461538461538462,0.7715384615384615,0.796923076923077,0.8223076923076923,0.8476923076923076,0.8730769230769231,0.8984615384615384,0.923846153846154,0.9492307692307692,0.9746153846153846,1.0,1.0333333333333334,1.0666666666666669,1.1,1.1333333333333333,1.1666666666666667,1.2,1.2333333333333334,1.2666666666666666,1.3,1.3333333333333333,1.3666666666666667,1.4,1.4333333333333331,1.4666666666666668,1.5,1.5333333333333332,1.5666666666666669,1.6,1.6333333333333333,1.6666666666666663,1.7,1.7333333333333334,1.7666666666666666,1.8,1.8333333333333333,1.8666666666666667,1.9,1.9333333333333331,1.9666666666666668,2.0,2.033333333333333,2.0666666666666664,2.1,2.1333333333333333,2.166666666666667,2.2,2.2333333333333334,2.2666666666666666,2.3,2.333333333333333,2.3666666666666667,2.4,2.4333333333333336,2.466666666666667,2.5,2.533333333333333,2.5666666666666664,2.6,2.6333333333333333,2.666666666666667,2.7,2.7333333333333334,2.7666666666666666,2.8,2.833333333333333,2.8666666666666667,2.9,2.9333333333333336,2.966666666666667,3.0],
# "Policy Scenario":["Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 1: RCT-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based CED","Policy 2: RWE-based

# %% [markdown]
# # Figure 2: Structural interpretation of the policy indifference bias (PIB) threshold using quantitative bias analysis

# %%
# Figure 2: PIB using QBA
# Data Preparation

# Read pib_p1
pib_p1_df = pd.read_csv(f"{fig_dat_path}/pib_p1.csv")
pib_p1_vals = pib_p1_df['pib_p1'].tolist()

# Define the bias funciton
def get_bias(p_u_sc, rr_ux, rr_uy):
    if p_u_sc <= 0:
        raise ValueError("p_u_sc must be > 0.")
    num = (1.0 / p_u_sc) + rr_ux * (rr_uy - 1.0)
    den = (1.0 / p_u_sc) + (rr_uy - 1.0)
    return num / den

p_u_sc_const = 0.2
rr_ux_min, rr_ux_max = 0.01, 5.3
rr_uy_min, rr_uy_max = 0.01, 5.3
step = 0.02 # Adjusted step size for better performance

rr_ux_vals = np.round(np.arange(rr_ux_min, rr_ux_max + 1e-12, step), 6)
rr_uy_vals = np.round(np.arange(rr_uy_min, rr_uy_max + 1e-12, step), 6)

df_plot2 = pd.DataFrame({
    "rr_ux": np.repeat(rr_ux_vals, len(rr_uy_vals)),
    "rr_uy": np.tile(rr_uy_vals, len(rr_ux_vals)),
})
df_plot2["bias"] = get_bias(p_u_sc_const, df_plot2["rr_ux"].to_numpy(), df_plot2["rr_uy"].to_numpy())

# Determine Policy Zones
if len(pib_p1_vals) >= 2:
    pib_min = min(pib_p1_vals)
    pib_max = max(pib_p1_vals)

    df_plot2['Policy_Zone'] = np.where(
        (df_plot2['bias'] > pib_min) & (df_plot2['bias'] < pib_max),
        'Policy 2: RWE-based CED',
        'Policy 1: RCT-based CED'
    )
else:
    pib_val = pib_p1_vals[0] if pib_p1_vals else NaN
    if pib_val > 1.0:
         df_plot2['Policy_Zone'] = np.where(df_plot2['bias'] < pib_val, 'Policy 2: RWE-based CED', 'Policy 1: RCT-based CED')
    else:
         df_plot2['Policy_Zone'] = np.where(df_plot2['bias'] > pib_val, 'Policy 2: RWE-based CED', 'Policy 1: RCT-based CED')


# Generate curves for each PIB
curves_data = []
a = 1.0 / p_u_sc_const

for val in pib_p1_vals:
    # Curve has vertical asymptote at rr_ux = val
    # Segments logic
    x_left = np.linspace(rr_ux_min, val - 0.05, 100)
    y_left = 1.0 + a * (val - 1.0) / (x_left - val)

    x_right = np.linspace(val + 0.05, rr_ux_max, 100)
    y_right = 1.0 + a * (val - 1.0) / (x_right - val)

    # Determine Line Type label
    lt_label = "PIB = 0.78" if val < 1.0 else "PIB = 1.31"

    df_left = pd.DataFrame({"rr_ux": x_left, "rr_uy": y_left, "PIB_Val": val, "Segment": "Left", "LineType": lt_label})
    df_right = pd.DataFrame({"rr_ux": x_right, "rr_uy": y_right, "PIB_Val": val, "Segment": "Right", "LineType": lt_label})

    tmp_df = pd.concat([df_left, df_right])

    # Filter within bounds
    tmp_df = tmp_df[(tmp_df["rr_uy"] >= rr_uy_min) & (tmp_df["rr_uy"] <= rr_uy_max)]

    if not tmp_df.empty:
        curves_data.append(tmp_df)

df_curves = pd.concat(curves_data) if curves_data else pd.DataFrame(columns=["rr_ux", "rr_uy", "PIB_Val", "Segment", "LineType"])
df_curves['Group_ID'] = df_curves['PIB_Val'].astype(str) + "_" + df_curves['Segment']

# %%
# Figure 2: PIB using QBA

# Define Linetypes mapping
linetypes_map = {
    "PIB = 0.78": "dotted",
    "PIB = 1.31": "dashed"
}

# Plotting
fig2 = (
    ggplot(df_plot2, aes("rr_ux", "rr_uy"))
    + geom_tile(aes(fill="Policy_Zone"))
    + scale_fill_manual(values=colors)
    + geom_line(data=df_curves, mapping=aes("rr_ux", "rr_uy", group="Group_ID", linetype="LineType"),
                color="black", size=1.0)
    + geom_text(x=1.7, y=2.2, label=f"PIB = {pib_p1_vals[1]:.2f}", color='black')
    + geom_text(x=1.0, y=1.3, label=f"PIB = {pib_p1_vals[0]:.2f}", color='black')

    + geom_segment(x=2.0, y=2.3, xend=2.3, yend=2.6,
                   arrow=arrow(type='closed', length=10, angle=20), color='black', size=0.5)
    + geom_segment(x=0.7, y=1.5, xend=0.2, yend=2.3,
                   arrow=arrow(type='closed', length=10, angle=20), color='black', size=0.5)
    + geom_segment(x=1.3, y=1.1, xend=2.0, yend=0.4,
                   arrow=arrow(type='closed', length=10, angle=20), color='black', size=0.5)

    + scale_linetype_manual(values=linetypes_map, guide='none')
    + coord_cartesian(xlim=(0.0, 5.2), ylim=(0.0, 5.2))
    + labs(
        x="Confounder-Treatment Association",
        y="Confounder-Outcome Association",
        fill="Policy"
    )
    + scale_x_continuous(format='.1f', limits=(0.0, 5.2), breaks=[1, 2, 3, 4, 5], expand=[0, 0])
    + scale_y_continuous(format='.1f', limits=(0.0, 5.2), breaks=[0, 1, 2, 3, 4, 5], expand=[0, 0])
    + theme_bw()
    + times_new_roman_theme
    + theme(legend_box="vertical", legend_title=element_blank())
)

fig2
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Figure 3: Sensitivity of the policy indifference bias (PIB) to the timing advantage of RWE and trial costs.

# %%
# Figure 3: Faceted Plot (3x3)
# Data Preparation

# Parameters for the grid
timing_options = [1, 2, 3]
cost_options = [0 * 1e6, 5 * 1e6, 10 * 1e6]
cost_labels = {
    0 * 1e6: "Trial costs: low ($0)",
    5 * 1e6: "Trial costs: mid ($5M)",
    10 * 1e6: "Trial costs: high ($10M)"
}

records_grid = []
pib_records = []

for dt in timing_options:
    for cost in cost_options:
        p1_vals = []
        p2_vals = []
        biases = []

        for b in bias_b_range:
            res = get_policy_nb(
                rr_prior_mean=rr_true,
                bias_b=b,
                delta_tau_rwe=dt,
                trial_cost=cost,
                n_out=n_out,
                n_in=n_in
            )

            p1 = res["p1"]
            p2 = res["p2"]
            val_prob_p1 = res["prob_p1"]

            val_p1 = np.mean(p1) / 1e3
            val_p2 = np.mean(p2) / 1e3

            p1_vals.append(val_p1)
            p2_vals.append(val_p2)
            biases.append(b)

            records_grid.append({
                "bias_b": b,
                "Net Benefit": val_p1,
                "Policy": "Policy 1: RCT-based CED",
                "Timing": f"RWE time advantage: {dt} year(s)",
                "Cost": cost_labels[cost],
                "prob_p1": val_prob_p1
            })
            records_grid.append({
                "bias_b": b,
                "Net Benefit": val_p2,
                "Policy": "Policy 2: RWE-based CED",
                "Timing": f"RWE time advantage: {dt} year(s)",
                "Cost": cost_labels[cost],
                "prob_p1": val_prob_p1
            })

        # Intersections of p1 and p2 curves
        diffs = np.array(p1_vals) - np.array(p2_vals)
        idx = np.where(np.diff(np.sign(diffs)))[0]

        current_intersects = []
        for i in idx:
            x1, x2 = biases[i], biases[i + 1]
            y1, y2 = diffs[i], diffs[i + 1]
            if not np.isclose(y2 - y1, 0.0):
                sect_x = x1 + (x2 - x1) * (0 - y1) / (y2 - y1)
                current_intersects.append(sect_x)

        pib_low = np.nan
        pib_high = np.nan

        if current_intersects:
            lows = [x for x in current_intersects if x < 1.0]
            highs = [x for x in current_intersects if x > 1.0]
            if lows:
                pib_low = min(lows)
            if highs:
                pib_high = max(highs)

        pib_records.append({
            "Timing": f"RWE time advantage: {dt} year(s)",
            "Cost": cost_labels[cost],
            "PIB_Low": pib_low,
            "PIB_High": pib_high
        })

df_grid = pd.DataFrame(records_grid)
df_pib = pd.DataFrame(pib_records)

# PRD = prob_p1 at bias_b == 1 for each (Timing, Cost)
prd_lookup = (
    df_grid.loc[np.isclose(df_grid["bias_b"], 1.0), ["Timing", "Cost", "prob_p1"]]
    .groupby(["Timing", "Cost"], as_index=False)["prob_p1"]
    .first()
    .rename(columns={"prob_p1": "PRD"})
)

df_pib = df_pib.merge(prd_lookup, on=["Timing", "Cost"], how="left")

# %%
# Figure 3: Faceted Plot (3x3)
# Save data

df_grid.to_csv(f"{fig_dat_path}/df_grid_p3.csv", index=False)
df_pib.to_csv(f"{fig_dat_path}/df_pib_p3.csv", index=False)

# %%
# Figure 3: Faceted Plot (3x3)
# Plotting

df_grid = pd.read_csv(f"{fig_dat_path}/df_grid_p3.csv")
df_pib = pd.read_csv(f"{fig_dat_path}/df_pib_p3.csv")

# Ordering
cost_order = ["Trial costs: low ($0)", "Trial costs: mid ($5M)", "Trial costs: high ($10M)"]
timing_order = [
    "RWE time advantage: 1 year(s)",
    "RWE time advantage: 2 year(s)",
    "RWE time advantage: 3 year(s)"
]

df_grid["Cost"] = pd.Categorical(df_grid["Cost"], categories=cost_order, ordered=True)
df_pib["Cost"] = pd.Categorical(df_pib["Cost"], categories=cost_order, ordered=True)
df_grid["Timing"] = pd.Categorical(df_grid["Timing"], categories=timing_order, ordered=True)
df_pib["Timing"] = pd.Categorical(df_pib["Timing"], categories=timing_order, ordered=True)

df_grid = df_grid.sort_values(by=["Timing", "Cost"])
df_pib = df_pib.sort_values(by=["Timing", "Cost"])

# If PRD missing (older csv), regenerate from df_grid
if "PRD" not in df_pib.columns:
    prd_lookup = (
        df_grid.loc[np.isclose(df_grid["bias_b"], 1.0), ["Timing", "Cost", "prob_p1"]]
        .groupby(["Timing", "Cost"], as_index=False)["prob_p1"]
        .first()
        .rename(columns={"prob_p1": "PRD"})
    )
    df_pib = df_pib.merge(prd_lookup, on=["Timing", "Cost"], how="left")

# Vertical line labels for PIB
df_int = pd.melt(
    df_pib,
    id_vars=["Timing", "Cost"],
    value_vars=["PIB_Low", "PIB_High"],
    value_name="x_intercept"
).dropna()

df_int["label"] = df_int["x_intercept"].map(lambda x: f"{x:.2f}")

# Global y-position for PIB labels
y_min = df_grid["Net Benefit"].min()
y_max = df_grid["Net Benefit"].max()
y_range = y_max - y_min
df_int["y_pos"] = df_int["variable"].apply(
    lambda x: y_min if x == "PIB_Low" else y_min + 0.15 * y_range
)

# PRD labels (one per facet)
panel_stats = (
    df_grid.groupby(["Timing", "Cost"], as_index=False)
    .agg(
        x_min=("bias_b", "min"),
        x_max=("bias_b", "max"),
        y_min=("Net Benefit", "min"),
        y_max=("Net Benefit", "max")
    )
)

df_prd = (
    df_pib[["Timing", "Cost", "PRD"]]
    .drop_duplicates()
    .merge(panel_stats, on=["Timing", "Cost"], how="left")
)

df_prd["x_pos"] = 1.95
df_prd["y_pos"] = 25.4
df_prd["prd_label"] = df_prd["PRD"].map(lambda v: f"PRD = {prd:.1%}")

fig3 = (
    ggplot(df_grid, aes(x="bias_b", y="Net Benefit", color="Policy"))
    + geom_line(size=1.0)
    + facet_grid(x="Cost", y="Timing", x_order=0)
    + scale_color_manual(values=colors)
    + geom_vline(
        data=df_int,
        mapping=aes(xintercept="x_intercept"),
        linetype="dashed",
        color="black"
    )
    + geom_label(
        data=df_int,
        mapping=aes(x="x_intercept", y="y_pos", label="label"),
        color="black",
        hjust=-0.1,
        vjust=0,
        fill="white"
    )
    + geom_label(
        data=df_prd,
        mapping=aes(x="x_pos", y="y_pos", label="prd_label"),
        inherit_aes=False,
        color="black",
        fill="white",
        hjust=0,
        vjust=1
    )
    + labs(
        x="RWE Bias Factor (B)",
        y="Population Expected Net Benefit ($ Billions)"
    )
    + theme_bw()
    + times_new_roman_theme
    + theme(
        legend_title=element_blank(),
        strip_text=element_text(size=12 * scaler)
    )
)

fig3
# Out:
# /tmp/ipython-input-25120/799237678.py:53: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grid.groupby(["Timing", "Cost"], as_index=False)
# <html lang="en">
#    <head>
#        <meta charset="UTF-8">
#        <style> html, body { margin: 0; padding: 0; } </style>
#        <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.2/js-package/distr/lets-plot.min.js"></script>
#    </head>
#    <body>
#           <div id="HGnxfr" ></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("HGnxfr");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "bias_b":[0.01,0.01,0.0353846153846153,0.0353846153846153,0.0607692307692307,0.0607692307692307,0.0861538461538461,0.0861538461538461,0.1115384615384615,0.1115384615384615,0.1369230769230769,0.1369230769230769,0.1623076923076923,0.1623076923076923,0.1876923076923076,0.1876923076923076,0.213076923076923,0.213076923076923,0.2384615384615384,0.2384615384615384,0.2638461538461538,0.2638461538461538,0.2892307692307692,0.2892307692307692,0.3146153846153846,0.3146153846153846,0.34,0.34,0.3653846153846153,0.3653846153846153,0.3907692307692307,0.3907692307692307,0.4161538461538461,0.4161538461538461,0.4415384615384615,0.4415384615384615,0.4669230769230769,0.4669230769230769,0.4923076923076923,0.4923076923076923,0.5176923076923077,0.5176923076923077,0.5430769230769231,0.5430769230769231,0.5684615384615385,0.5684615384615385,0.5938461538461538,0.5938461538461538,0.6192307692307693,0.6192307692307693,0.6446153846153846,0.6446153846153846,0.67,0.67,0.6953846153846154,0.6953846153846154,0.7207692307692307,0.7207692307692307,0.7461538461538462,0.7461538461538462,0.7715384615384615,0.7715384615384615,0.796923076923077,0.796923076923077,0.8223076923076923,0.8223076923076923,0.8476923076923076,0.8476923076923076,0.8730769230769231,0.8730769230769231,0.8984615384615384,0.8984615384615384,0.923846153846154,0.923846153846154,0.9492307692307692,0.9492307692307692,0.9746153846153846,0.9746153846153846,1.0,1.0,1.0333333333333334,1.0333333333333334,1.0666666666666669,1.0666666666666669,1.1,1.1,1.1333333333333333,1.1333333333333333,1.1666666666666667,1.1666666666666667,1.2,1.2,1.2333333333333334,1.2333333333333334,1.2666666666666666,1.2666666666666666,1.3,1.3,1.3333333333333333,1.3333333333333333,1.3666666666666667,1.3666666666666667,1.4,1.4,1.4333333333333331,1.4333333333333331,1.4666666666666668,1.4666666666666668,1.5,1.5,1.5333333333333332,1.5333333333333332,1.5666666666666669,1.5666666666666669,1.6,1.6,1.6333333333333333,1.6333333333333333,1.6666666666666663,1.6666666666666663,1.7,1.7,1.7333333333333334,1.7333333333333334,1.7666666666666666,1.7666666666666666,1.8,1.8,1.8333333333333333,1.8333333333333333,1.8666666666666667,1.8666666666666667,1.9,1.9,1.9333333333333331,1.9333333333333331,1.9666666666666668,1.9666666666666668,2.0,2.0,2.033333333333333,2.033333333333333,2.0666666666666664,2.0666666666666664,2.1,2.1,2.1333333333333333,2.1333333333333333,2.166666666666667,2.166666666666667,2.2,2.2,2.2333333333333334,2.2333333333333334,2.2666666666666666,2.2666666666666666,2.3,2.3,2.333333333333333,2.333333333333333,2.3666666666666667,2.3666666666666667,2.4,2.4,2.4333333333333336,2.4333333333333336,2.466666666666667,2.466666666666667,2.5,2.5,2.533333333333333,2.533333333333333,2.5666666666666664,2.5666666666666664,2.6,2.6,2.6333333333333333,2.6333333333333333,2.666666666666667,2.666666666666667,2.7,2.7,2.7333333333333334,2.7333333333333334,2.7666666666666666,2.7666666666666666,2.8,2.8,2.833333333333333,2.833333333333333,2.8666666666666667,2.8666666666666667,2.9,2.9,2.9333333333333336,2.9333333333333336,2.966666666666667,2.966666666666667,3.0,3.0,0.01,0.01,0.0353846153846153,0.0353846153846153,0.0607692307692307,0.0607692307692307,0.0861538461538461,0.0861538461538461,0.1115384615384615,0.1115384615384615,0.1369230769230769,0.1369230769230769,0.1623076923076923,0.1623076923076923,0.1876923076923076,0.1876923076923076,0.213076923076923,0.213076923076923,0.2384615384615384,0.2384615384615384,0.2638461538461538,0.2638461538461538,0.2892307692307692,0.2892307692307692,0.3146153846153846,0.3146153846153846,0.34,0.34,0.3653846153846153,0.3653846153846153,0.3907692307692307,0.3907692307692307,0.4161538461538461,0.4161538461538461,0.4415384615384615,0.4415384615384615,0.4669230769230769,0.4669230769230769,0.4923076923076923,0.4923076923076923,0.5176923076923077,0.5176923076923077,0.5430769230769231,0.5430769230769231,0.5684615384615385,0.5684615384615385,0.5938461538461538,0.5938461538461538,0.6192307692307693,0.6192307692307693,0.6446153846153846,0.6446153846153 ...

# %% [markdown]
# # Save figures

# %%
figure_path = "/content/drive/MyDrive/Research/02_VOI_RWE_QBA/03_output/figure"

ggsave(plot=fig1, filename=f"{figure_path}/01_NB_Bias.html")
ggsave(plot=fig2, filename=f"{figure_path}/02_Bias_Interaction.html")
ggsave(plot=fig3, filename=f"{figure_path}/03_Time_Advantage.html")
# Out:
# '/content/drive/MyDrive/Research/02_VOI_RWE_QBA/03_output/figure/03_Time_Advantage.html'
